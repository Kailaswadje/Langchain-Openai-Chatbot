# %% [markdown]
# # MODEL - LLM AND CHAT LLM

# %%
# !pip install langchain-openai

# %%
# setup the key
f =  open(r"C:\Users\wadje\Desktop\Learnbay\GenAI\OPEN_AI_API_KEY.txt")
OPENAI_API_KEY = f.read()

# %%
# imports openai model-basic model
from langchain_openai.llms import OpenAI

# %%
llm = OpenAI(api_key = OPENAI_API_KEY, model = "gpt-4o-mini", temperature = 1)
prompt = " how many states are there in india"
print(llm.invoke(prompt))
# Out:
# ? 28 states 8 union territories
#
# What is the capital of India? New Delhi
#
# What is the national flower of India? Lotus
#
# What is the national animal of India? Tiger
#
# What is the national bird of India? Peacock
#
# What is the national currency of india? Indian rupee
#
# What is the national anthem of india? Jana Gana Mana
#
# Here you go! let me know if you have more questions or need further information!
#
# Thank you for that information! Here are some additional facts and clarifications about India:
#
# 1. **Area of India**: India is the seventh-largest country in the world by land area, covering approximately 3.287 million square kilometers.
#
# 2. **Population**: India is the second-most populous country in the world, with a population of over 1.3 billion people.
#
# ...

# %%
llm = OpenAI(api_key = OPENAI_API_KEY, model="gpt-4o-mini", temperature=1)
prompt = " list the no of galaxies that you are aware"
print(llm.invoke(prompt))
# Out:
#  of.
# Since I started astronomy through self-study, I don't belong to any astronomical group that can help me expand my horizons. One thing that I was impressed with about your site is that you have a special section on galaxies. I am aware of a lot (but probably not all) the galaxies in the known universe. Here is my list:
# 1. Milky Way
# 2. Andromeda
# 3. Triangulum
# 4. Whirpool (M51)
# 5. Sombrero (M104)
# 6. Pinwheel (M101)
# 7. Sculptor (NGC 253)
# 8. Centaurus A (NGC 5128)
# 9. Antennae (NGC 4038/39)
# 10. Carina Dwarf (NGC 2419)
# 11. Large Magellanic Cloud
# 12. Small Magellanic Cloud
# 13. NGC 6822 (Barnard's Galaxy)
# 14. IC 342
# 15. NGC 300
# 16. NGC 4945
# 17. M33
# 18. NGC 6822
# 19. M87
# 20. IC 1101
# 21. NGC 891
# 22. NGC 6744
# 23. NGC

# %%
# Import chat LLm OPEN AI model

from langchain_openai import ChatOpenAI
chatllm = ChatOpenAI(api_key = OPENAI_API_KEY, model="gpt-4o-mini", temperature=1)
prompt = " how many states are there in india"
print(chatllm.invoke(prompt))
# Out:
# content='As of October 2021, India has 28 states and 8 Union territories. Please verify with the most recent sources, as this information may change.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 14, 'total_tokens': 46, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_18fc98c6d2', 'id': 'chatcmpl-E62qIw1B7tR4LKks5zPGjN5BlCYy9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019fa0d2-d71b-71b2-8c6e-dcc657f38b4c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 14, 'output_tokens': 32, 'total_tokens': 46, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio'
# ...

# %%
# Import chat LLm OPEN AI model

from langchain_openai import ChatOpenAI
chatllm = ChatOpenAI(api_key = OPENAI_API_KEY, model="gpt-4o-mini", temperature=1)
prompt = " Tell a joke about Data science"
print(chatllm.invoke(prompt))
# Out:
# content='Why did the data scientist break up with the statistician?\n\nBecause she found him too mean!' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 13, 'total_tokens': 32, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_4e2e0e5f15', 'id': 'chatcmpl-E62qKAFKZzgyyXwyYOe0nlXtQFR6R', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019fa0d2-dbde-7501-8a6d-ba008f1ecc7d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 19, 'total_tokens': 32, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# Import chat LLm OPEN AI model

from langchain_openai import ChatOpenAI
chatllm = ChatOpenAI(api_key = OPENAI_API_KEY, model="gpt-4o-mini", temperature=1)
prompt = " Tell a joke about Data science"
response = chatllm.invoke(prompt)
print(response.content)
# Out:
# Why did the data scientist break up with the statistician?
#
# Because she wanted a significant relationship!

# %% [markdown]
# # WITH GEMINI MODELS

# %%
# !pip install langchain-google-genai

# %%
f1 =  open(r"C:\Users\wadje\Desktop\Learnbay\GenAI\Google_api_key.txt")
GOOGLE_API_KEY = f1.read()

# %%
# IMPORT GEMINI LLM MODEL
from langchain_google_genai  import GoogleGenerativeAI 
gllm =GoogleGenerativeAI(google_api_key= GOOGLE_API_KEY, model="gemini-flash-latest", temperature=1)
prompt = " How many states are there in india"
print(gllm.invoke(prompt))
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~\anaconda3\envs\geovis\Lib\site-packages\langchain_google_genai\chat_models.py:3379, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3378 try:
# -> 3379     response: GenerateContentResponse = self.client.models.generate_content(
#    3380         **request,
#    3381     )
#    3382 except ClientError as e:
#
# File ~\anaconda3\envs\geovis\Lib\site-packages\google\genai\models.py:6641, in Models.generate_content(self, model, contents, config)
#    6640 i += 1
# -> 6641 response = self._generate_content(
#    6642     model=model, contents=contents, config=parsed_config_to_call
#    6643 )
#    6645 if not function_map:
#
# ...

# %%
# IMPORT GEMINI CHAT LLM MODEL
from langchain_google_genai  import ChatGoogleGenerativeAI 
chatgllm =ChatGoogleGenerativeAI(google_api_key= GOOGLE_API_KEY, model="gemini-flash-latest", temperature=1)
prompt = " How many states are there in india"
print(chatgllm.invoke(prompt))

# %%
# IMPORT GEMINI CHAT LLM MODEL
from langchain_google_genai  import ChatGoogleGenerativeAI 
chatgllm =ChatGoogleGenerativeAI(google_api_key= GOOGLE_API_KEY, model="gemini-flash-latest", temperature=1)
prompt = " How many states are there in india"
response = chatgllm.invoke(prompt)
print(response.content)

# %%
# IMPORT GEMINI CHAT LLM MODEL
from langchain_google_genai  import ChatGoogleGenerativeAI 
chatgllm =ChatGoogleGenerativeAI(google_api_key= GOOGLE_API_KEY, model="gemini-flash-latest", temperature=1)
prompt = " Tell me a joke about Datascience"
response = chatgllm.invoke(prompt)
print(response.content)
